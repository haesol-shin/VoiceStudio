# %%
import sys
from unittest.mock import MagicMock

sys.modules["pysptk"] = MagicMock()
sys.modules["pysptk.synthesis"] = MagicMock()
sys.modules["pysptk.util"] = MagicMock()
sys.modules["pkg_resources"] = MagicMock()

# %%
import torch
from torch.utils.data import DataLoader

from spk_incon.datasets import LIBRITTS_P, LIBRITTS_P_Custom

# %%
#ds = LIBRITTS_P_Custom(
#    root="./data",
#    url="train-clean-100",
#    download=True,
#    annotator="df3",
#)
# Out:
# [INFO] Loading cached dataset from data/.cache/libritts_p_train-clean-100/dataset...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ds = LIBRITTS_P_Custom(
#       2     root="./data",
#       3     url="train-clean-100",
#       4     download=True,
#       5     annotator="df3",
#       6 )
#
# File ~/t2a_voicestudio/speakerinc/spk_incon/datasets/libritts_p_custom.py:71, in LIBRITTS_P_Custom.__init__(self, root, url, annotator, max_z_score, transform, download, force_reload)
#      68 self.cache_dir.mkdir(parents=True, exist_ok=True)
#      70 self.data_source = self._load_or_create_dataset(force_reload)
# ---> 71 self.style_map, self.speaker_map = load_libritts_p_prompts(self.root, self.annotator)
#      73 self._filter_outliers()
#
# File ~/t2a_voicestudio/speakerinc/spk_incon/datasets/libritts_p3.py:157, in load_libritts_p_prompts(root, annotator)
#     154         speaker_path = alt_path
#     156 if not os.path.isfile(speaker_path):
# --> 157      raise RuntimeError(f"Speaker prompt file not found for {annotator}")
#     159 speaker_df = pd.read_csv(
#     160     speaker_path,
#     161     sep='|',
#     162     header=None,
#     163     names=['spk_id', 'speaker_prompt'],
#     164 )
#     165 speaker_prompts = {
#     166     int(row.spk_id): row.speaker_prompt.split(",")
#     167     for row in speaker_df.itertuples(index=False)
#     168 }
#
# RuntimeError: Speaker prompt file not found for df3

# %%
ds = LIBRITTS_P_Custom(root="./data")
# Out:
# [INFO] Loading cached dataset from data/.cache/libritts_p_train-clean-100/dataset...
# [INFO] Filtering outliers (max_z_score=3.5)...
# [INFO] Filtered: 33187 -> 31504 samples.

# %%
ds[20_000]
# Out:
# {'waveform': tensor([[-0.0004, -0.0004, -0.0003,  ..., -0.0006, -0.0005, -0.0003]]),
#  'sample_rate': 24000,
#  'original_text': 'Like Louis the fourteenth., she liked to be driven at a gallop.',
#  'normalized_text': 'Like Louis the fourteenth., she liked to be driven at a gallop.',
#  'style_prompts': ['Ask a ordinary woman to talk to me',
#   'Ask a woman to speak with normal pitch, normal speaking speed and standard volume',
#   'Ask a woman to speak with normal pitch, speaking speed and standard volume',
#   'Ask a woman to speak with standard pitch, speaking speed and energy',
#   'Ask a woman to talk in a normal speaking style, with a normal pitch, speed, and energy',
#   'Ask a woman to talk in a normal speaking style, with normal pitch, speed, and energy',
#   'Ask a woman to talk in normal speaking style, with normal pitch, speed, and energy',
#   'Ask a woman to talk to me with normal pitch, normal speaking speed and standard volume',
#   'Ask a woman to talk with a normal speaking speed, pitch and volume',
#   'Ask a woman to talk with normal pitch, normal speaking speed and standard volume',
#   'Ask a woman to talk with normal pitch, speaking speed and energy',
#   'Ask a woman to talk with normal speaking speed, pitch and volume',
#   'Let a woman speak with standard pitch, speaking speed and energy',
#   'Let a woman speaks with standard pitch, speaking speed and energy',
#   'ask a woman to talk with normal speaking speed, pitch and volume',
#   'let a woman speaks with standard pitch, speaking speed and energy'],
#  'speaker_prompts': ['feminine',
#   'adult-like',
#   'tensed',
#   'powerful',
#   'slightly hard',
#   'clear',
#   'fluent',
#   'intellectual',
#   'calm',
#   'elegant',
#   'sexy',
#   'lively',
#   'sharp'],
#  'combined_prompt': "Let a woman speaks with standard pitch, speaking speed and energy The speaker's identity can be described as sharp, feminine, intellectual, sexy, calm, elegant, lively, adult-like, powerful, tensed, fluent, slightly hard, clear.",
#  'utterance_id': '6147_34607_000005_000004',
#  'speaker_id': 6147,
#  'group_id': 'set_848ee47bb3be',
#  'group_size': 46,
#  'distance_z_score': 0.532866895198822,
#  'intra_group_distance': 0.12127924}

# %%
from IPython.display import Audio

item = ds[50]
Audio(item['waveform'][0], rate=item['sample_rate'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
